# %%
from pathlib import Path

import numpy as np
import pandas as pd

import config

#最大表示列数の指定（ここでは50列を指定）
pd.set_option('display.max_columns', 50)

def make_data_dirs(dirname: str):
    if not os.path.exists(dirname):
        os.makedirs(dirname)

# %% [markdown]
# ## data_clinical_patient

# %%
make_data_dirs(config.INTERUM_BRCA_METABRIC_DIR)

# %%
pd.read_table(config.BRCA_METABRIC_DIR + "/data_clinical_patient.txt").head(4).to_csv(config.INTERUM_BRCA_METABRIC_DIR+'/data_clinical_patient_head.csv')

# %%
pd.read_table(config.BRCA_METABRIC_DIR + "/data_clinical_patient.txt").head(8)
# Out:
#                           #Patient Identifier  Lymph nodes examined positive  \
# 0  #Identifier to uniquely specify a patient.  Number of lymphnodes positive
# 1                                     #STRING                         STRING
# 2                                          #1                              1
# 3                                  PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE
# 4                                     MB-0000                             10
# 5                                     MB-0002                              0
# 6                                     MB-0005                              1
# 7                                     MB-0006                              3
#
#    Nottingham prognostic index    Cellularity   Chemotherapy   Cohort  \
# 0  Nottingham prognostic index  Tumor Content  Chemotherapy.  Cohort.
# 1                       NUMBER         STRING         STRING   STRING
# ...

# %%
pd.read_table(config.BRCA_METABRIC_DIR + "/data_clinical_patient.txt").tail()
# Out:
#      #Patient Identifier Lymph nodes examined positive  \
# 2508           MTS-T2428                             0
# 2509           MTS-T2429                             0
# 2510           MTS-T2430                             0
# 2511           MTS-T2431                             0
# 2512           MTS-T2432                             0
#
#      Nottingham prognostic index Cellularity Chemotherapy Cohort  \
# 2508                        2.54         NaN          NaN      1
# 2509                        4.56         NaN          NaN      1
# 2510                         NaN         NaN          NaN    NaN
# 2511                         NaN         NaN          NaN    NaN
# 2512                         NaN         NaN          NaN    NaN
#
#      ER status measured by IHC HER2 status measured by SNP6 Hormone Therapy  \
# 2508                   Positve                          NaN             NaN
# 2509                   Positve                          NaN             NaN
# ...
