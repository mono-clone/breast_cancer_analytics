# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sweetviz as sv
import dtale

import config

#最大表示列数の指定（ここでは50列を指定）
pd.set_option('display.max_columns', 50)

def make_dir(dir_name: str):
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)

# %%
df_patient=pd.read_table(config.RAW_BRCA_METABRIC_DIR+'/data_clinical_patient.txt',header=4)
df_patient.head()
# Out:
#   PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY CHEMOTHERAPY  \
# 0    MB-0000                           10.0  6.044         NaN           NO
# 1    MB-0002                            0.0  4.020        High           NO
# 2    MB-0005                            1.0  4.030        High          YES
# 3    MB-0006                            3.0  4.050    Moderate          YES
# 4    MB-0008                            8.0  6.080        High          YES
#
#    COHORT   ER_IHC HER2_SNP6 HORMONE_THERAPY INFERRED_MENOPAUSAL_STATE  \
# 0     1.0  Positve   NEUTRAL             YES                      Post
# 1     1.0  Positve   NEUTRAL             YES                       Pre
# 2     1.0  Positve   NEUTRAL             YES                       Pre
# 3     1.0  Positve   NEUTRAL             YES                       Pre
# 4     1.0  Positve   NEUTRAL             YES                      Post
#
#       SEX INTCLUST  AGE_AT_DIAGNOSIS   OS_MONTHS   OS_STATUS CLAUDIN_SUBTYPE  \
# 0  Female     4ER+             75.65  140.500000    0:LIVING     claudin-low
# 1  Female     4ER+             43.19   84.633333    0:LIVING            LumA
# 2  Female        3             48.87  163.700000  1:DECEASED            LumB
# 3  Female        9             47.68  164.933333    0:LIVING            LumB
# 4  Female        9             76.97   41.366667  1:DECEASED            LumB
#
#                THREEGENE     VITAL_STATUS LATERALITY RADIO_THERAPY  \
# 0              ER-/HER2-           Living      Right           YES
# 1  ER+/HER2- High Prolif           Living      Right           YES
# 2                    NaN  Died of Disease      Right            NO
# 3                    NaN           Living      Right           YES
# 4  ER+/HER2- High Prolif  Died of Disease      Right           YES
#
#   HISTOLOGICAL_SUBTYPE     BREAST_SURGERY      RFS_STATUS  RFS_MONTHS
# 0           Ductal/NST         MASTECTOMY  0:Not Recurred      138.65
# 1           Ductal/NST  BREAST CONSERVING  0:Not Recurred       83.52
# 2           Ductal/NST         MASTECTOMY      1:Recurred      151.28
# 3                Mixed         MASTECTOMY  0:Not Recurred      162.76
# 4                Mixed         MASTECTOMY      1:Recurred       18.55

# %%
df_patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2509 entries, 0 to 2508
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PATIENT_ID                     2509 non-null   object
#  1   LYMPH_NODES_EXAMINED_POSITIVE  2243 non-null   float64
#  2   NPI                            2287 non-null   float64
#  3   CELLULARITY                    1917 non-null   object
#  4   CHEMOTHERAPY                   1980 non-null   object
#  5   COHORT                         2498 non-null   float64
#  6   ER_IHC                         2426 non-null   object
#  7   HER2_SNP6                      1980 non-null   object
#  8   HORMONE_THERAPY                1980 non-null   object
#  9   INFERRED_MENOPAUSAL_STATE      1980 non-null   object
#  10  SEX                            2509 non-null   object
#  11  INTCLUST                       1980 non-null   object
#  12  AGE_AT_DIAGNOSIS               2498 non-null   float64
#  13  OS_MONTHS                      1981 non-null   float64
#  14  OS_STATUS                      1981 non-null   object
#  15  CLAUDIN_SUBTYPE                1980 non-null   object
#  16  THREEGENE                      1764 non-null   object
#  17  VITAL_STATUS                   1980 non-null   object
#  18  LATERALITY                     1870 non-null   object
#  19  RADIO_THERAPY                  1980 non-null   object
#  20  HISTOLOGICAL_SUBTYPE           2374 non-null   object
#  21  BREAST_SURGERY                 1955 non-null   object
#  22  RFS_STATUS                     2488 non-null   object
#  23  RFS_MONTHS                     2388 non-null   float64
# dtypes: float64(6), object(18)
# memory usage: 470.6+ KB

# %%
dtale.show(df_patient)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://MBA-masanari.local:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 特徴量の型に合わせたエンコーディング

# %%
df_patient_converted=df_patient.copy()

# %%
# astypeするためのdict作成
def list2dict(str_dtype: str, columns:list, dic:dict={}) -> dict:
    for column in columns:
        dic[column]=str_dtype
    return dic

# %%
target_columns=[
    'OS_MONTHS',
    'OS_STATUS',
    'RFS_STATUS',
    'RFS_MONTHS',
    'VITAL_STATUS',
]

int_columns=[
    'LYMPH_NODES_EXAMINED_POSITIVE',
]

float_columns=[
    'NPI',
    'AGE_AT_DIAGNOSIS',
]

str_columns=[
]

# 質的変数（順序尺度）
qualitative_ordinal_columns=[
    'CELLULARITY',  
    'ER_IHC',
    'HER2_SNP6',
    'INFERRED_MENOPAUSAL_STATE',
]
# 質的変数（名義尺度）
qualitative_name_columns=[
    'COHORT',
    'INTCLUST',
    'CLAUDIN_SUBTYPE',
    'THREEGENE',
    'HISTOLOGICAL_SUBTYPE',
    'BREAST_SURGERY',
    'LATERALITY',
]

bool_columns=[
    'CHEMOTHERAPY',
    'HORMONE_THERAPY',
    'RADIO_THERAPY',
]

meanless_columns=[
    'PATIENT_ID',
    'SEX',
]

print(df_patient.shape[1],
    len(target_columns)+\
    len(int_columns)+\
    len(float_columns)+\
    len(str_columns)+\
    len(qualitative_ordinal_columns)+\
    len(qualitative_name_columns)+\
    len(bool_columns)+\
    len(meanless_columns))
assert  df_patient.shape[1]==\
    len(target_columns)+\
    len(int_columns)+\
    len(float_columns)+\
    len(str_columns)+\
    len(qualitative_ordinal_columns)+\
    len(qualitative_name_columns)+\
    len(bool_columns)+\
    len(meanless_columns), 'lack or too much columns'
# Out:
# 24 24
# Executing shutdown due to inactivity...
# 2022-04-17 00:35:03,463 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# 2022-04-17 00:35:03,504 - INFO     - Executing shutdown...

# %% [markdown]
# ### 質的変数（順序尺度）のエンコーディング

# %%
qualitative_ordinal_columns
# Out:
# ['CELLULARITY', 'ER_IHC', 'HER2_SNP6', 'INFERRED_MENOPAUSAL_STATE']

# %%
for i in qualitative_ordinal_columns:
    display(df_patient[i].unique())
# Out:
# array([nan, 'High', 'Moderate', 'Low'], dtype=object)
# array(['Positve', 'Negative', nan], dtype=object)
# array(['NEUTRAL', 'LOSS', nan, 'GAIN', 'UNDEF'], dtype=object)
# array(['Post', 'Pre', nan], dtype=object)

# %%
df_patient_converted['CELLULARITY_converted']=df_patient_converted['CELLULARITY'].map({'High':3,'Moderate':2,'Low':1})
df_patient_converted['ER_IHC_converted']=df_patient_converted['ER_IHC'].map({'Positve':1, 'Negative':-1})
df_patient_converted['HER2_SNP6_converted']=df_patient_converted['HER2_SNP6'].map({'GAIN':3, 'NEUTRAL':2, 'LOSS':1, 'UNDEF':0})
df_patient_converted['INFERRED_MENOPAUSAL_STATE_converted']=df_patient_converted['INFERRED_MENOPAUSAL_STATE'].map({'Post':1, 'Pre':-1})

qualitative_ordinal_columns=[
    'CELLULARITY_converted',
    'ER_IHC_converted',
    'HER2_SNP6_converted',
    'INFERRED_MENOPAUSAL_STATE_converted',
]

df_patient_converted=df_patient_converted.drop(['CELLULARITY', 'ER_IHC', 'HER2_SNP6', 'INFERRED_MENOPAUSAL_STATE'], axis=1)

# %% [markdown]
# ### boolのエンコーディング
#
# astype(bool)のみではうまく変換されなかった

# %%
bool_columns
# Out:
# ['CHEMOTHERAPY', 'HORMONE_THERAPY', 'RADIO_THERAPY']

# %%
for i in bool_columns:
    display(df_patient[i].unique())
# Out:
# array(['NO', 'YES', nan], dtype=object)
# array(['YES', 'NO', nan], dtype=object)
# array(['YES', 'NO', nan], dtype=object)

# %%
df_patient_converted['CHEMOTHERAPY_converted']=df_patient_converted['CHEMOTHERAPY'].map({'YES':1,'NO':0})
df_patient_converted['HORMONE_THERAPY_converted']=df_patient_converted['HORMONE_THERAPY'].map({'YES':1,'NO':0})
df_patient_converted['RADIO_THERAPY_converted']=df_patient_converted['RADIO_THERAPY'].map({'YES':1,'NO':0})

bool_columns=[
    'CHEMOTHERAPY_converted',
    'HORMONE_THERAPY_converted',
    'RADIO_THERAPY_converted',
]

df_patient_converted=df_patient_converted.drop(['CHEMOTHERAPY', 'HORMONE_THERAPY', 'RADIO_THERAPY'], axis=1)

# %%
astype_dict={}
astype_dict=list2dict('float', int_columns)
astype_dict=list2dict('float', float_columns)
astype_dict=list2dict('str', str_columns)
astype_dict=list2dict('float', qualitative_ordinal_columns)
astype_dict=list2dict('str', qualitative_name_columns)
astype_dict=list2dict('bool', bool_columns)
display(astype_dict, len(astype_dict))
assert len(astype_dict)+len(target_columns)+len(meanless_columns)== df_patient_converted.shape[1], 'lack or too much columns'
# Out:
# {'LYMPH_NODES_EXAMINED_POSITIVE': 'float',
#  'NPI': 'float',
#  'AGE_AT_DIAGNOSIS': 'float',
#  'CELLULARITY_converted': 'float',
#  'ER_IHC_converted': 'float',
#  'HER2_SNP6_converted': 'float',
#  'INFERRED_MENOPAUSAL_STATE_converted': 'float',
#  'COHORT': 'str',
#  'INTCLUST': 'str',
#  'CLAUDIN_SUBTYPE': 'str',
#  'THREEGENE': 'str',
#  'HISTOLOGICAL_SUBTYPE': 'str',
#  'BREAST_SURGERY': 'str',
#  'LATERALITY': 'str',
#  'CHEMOTHERAPY_converted': 'bool',
#  'HORMONE_THERAPY_converted': 'bool',
#  'RADIO_THERAPY_converted': 'bool'}
# 17

# %%
df_patient_converted=df_patient_converted.astype(astype_dict)
df_patient_converted.dtypes
# Out:
# PATIENT_ID                              object
# LYMPH_NODES_EXAMINED_POSITIVE          float64
# NPI                                    float64
# COHORT                                  object
# SEX                                     object
# INTCLUST                                object
# AGE_AT_DIAGNOSIS                       float64
# OS_MONTHS                              float64
# OS_STATUS                               object
# CLAUDIN_SUBTYPE                         object
# THREEGENE                               object
# VITAL_STATUS                            object
# LATERALITY                              object
# HISTOLOGICAL_SUBTYPE                    object
# BREAST_SURGERY                          object
# RFS_STATUS                              object
# RFS_MONTHS                             float64
# CELLULARITY_converted                  float64
# ER_IHC_converted                       float64
# HER2_SNP6_converted                    float64
# INFERRED_MENOPAUSAL_STATE_converted    float64
# CHEMOTHERAPY_converted                    bool
# HORMONE_THERAPY_converted                 bool
# RADIO_THERAPY_converted                   bool
# dtype: object

# %%
df_patient.head()
# Out:
#   PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY CHEMOTHERAPY  \
# 0    MB-0000                           10.0  6.044         NaN           NO
# 1    MB-0002                            0.0  4.020        High           NO
# 2    MB-0005                            1.0  4.030        High          YES
# 3    MB-0006                            3.0  4.050    Moderate          YES
# 4    MB-0008                            8.0  6.080        High          YES
#
#    COHORT   ER_IHC HER2_SNP6 HORMONE_THERAPY INFERRED_MENOPAUSAL_STATE  \
# 0     1.0  Positve   NEUTRAL             YES                      Post
# 1     1.0  Positve   NEUTRAL             YES                       Pre
# 2     1.0  Positve   NEUTRAL             YES                       Pre
# 3     1.0  Positve   NEUTRAL             YES                       Pre
# 4     1.0  Positve   NEUTRAL             YES                      Post
#
#       SEX INTCLUST  AGE_AT_DIAGNOSIS   OS_MONTHS   OS_STATUS CLAUDIN_SUBTYPE  \
# 0  Female     4ER+             75.65  140.500000    0:LIVING     claudin-low
# 1  Female     4ER+             43.19   84.633333    0:LIVING            LumA
# 2  Female        3             48.87  163.700000  1:DECEASED            LumB
# 3  Female        9             47.68  164.933333    0:LIVING            LumB
# 4  Female        9             76.97   41.366667  1:DECEASED            LumB
#
#                THREEGENE     VITAL_STATUS LATERALITY RADIO_THERAPY  \
# 0              ER-/HER2-           Living      Right           YES
# 1  ER+/HER2- High Prolif           Living      Right           YES
# 2                    NaN  Died of Disease      Right            NO
# 3                    NaN           Living      Right           YES
# 4  ER+/HER2- High Prolif  Died of Disease      Right           YES
#
#   HISTOLOGICAL_SUBTYPE     BREAST_SURGERY      RFS_STATUS  RFS_MONTHS
# 0           Ductal/NST         MASTECTOMY  0:Not Recurred      138.65
# 1           Ductal/NST  BREAST CONSERVING  0:Not Recurred       83.52
# 2           Ductal/NST         MASTECTOMY      1:Recurred      151.28
# 3                Mixed         MASTECTOMY  0:Not Recurred      162.76
# 4                Mixed         MASTECTOMY      1:Recurred       18.55

# %%
df_patient_converted.head()
# Out:
#   PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE    NPI COHORT     SEX INTCLUST  \
# 0    MB-0000                           10.0  6.044    1.0  Female     4ER+
# 1    MB-0002                            0.0  4.020    1.0  Female     4ER+
# 2    MB-0005                            1.0  4.030    1.0  Female        3
# 3    MB-0006                            3.0  4.050    1.0  Female        9
# 4    MB-0008                            8.0  6.080    1.0  Female        9
#
#    AGE_AT_DIAGNOSIS   OS_MONTHS   OS_STATUS CLAUDIN_SUBTYPE  \
# 0             75.65  140.500000    0:LIVING     claudin-low
# 1             43.19   84.633333    0:LIVING            LumA
# 2             48.87  163.700000  1:DECEASED            LumB
# 3             47.68  164.933333    0:LIVING            LumB
# 4             76.97   41.366667  1:DECEASED            LumB
#
#                THREEGENE     VITAL_STATUS LATERALITY HISTOLOGICAL_SUBTYPE  \
# 0              ER-/HER2-           Living      Right           Ductal/NST
# 1  ER+/HER2- High Prolif           Living      Right           Ductal/NST
# 2                    nan  Died of Disease      Right           Ductal/NST
# 3                    nan           Living      Right                Mixed
# 4  ER+/HER2- High Prolif  Died of Disease      Right                Mixed
#
#       BREAST_SURGERY      RFS_STATUS  RFS_MONTHS  CELLULARITY_converted  \
# 0         MASTECTOMY  0:Not Recurred      138.65                    NaN
# 1  BREAST CONSERVING  0:Not Recurred       83.52                    3.0
# 2         MASTECTOMY      1:Recurred      151.28                    3.0
# 3         MASTECTOMY  0:Not Recurred      162.76                    2.0
# 4         MASTECTOMY      1:Recurred       18.55                    3.0
#
#    ER_IHC_converted  HER2_SNP6_converted  INFERRED_MENOPAUSAL_STATE_converted  \
# 0               1.0                  2.0                                  1.0
# 1               1.0                  2.0                                 -1.0
# 2               1.0                  2.0                                 -1.0
# 3               1.0                  2.0                                 -1.0
# 4               1.0                  2.0                                  1.0
#
#    CHEMOTHERAPY_converted  HORMONE_THERAPY_converted  RADIO_THERAPY_converted
# 0                   False                       True                     True
# 1                   False                       True                     True
# 2                    True                       True                    False
# 3                    True                       True                     True
# 4                    True                       True                     True

# %%
# pickleとして保存
make_dir(config.INTERIM_PICKLE_EDA_DIR)
df_patient_converted.to_pickle(config.INTERIM_PICKLE_EDA_DIR+'/data_clinical_patient_1.0.pkl')

# %%
target = 'OS_MONTHS'
target_column=[target]
drop_columns=[i for i in target_columns+meanless_columns if i not in target_column]

# %% [markdown]
# データの分割

# %%
df_patient_MB=df_patient[df_patient['PATIENT_ID'].str.contains('MB')]
df_patient_MTST=df_patient[df_patient['PATIENT_ID'].str.contains('MTS-T')]

# %%
df_patient_MB.describe()
# Out:
#        LYMPH_NODES_EXAMINED_POSITIVE          NPI       COHORT  \
# count                    1909.000000  1984.000000  1985.000000
# mean                        2.004715     4.013186     2.616121
# std                         4.080490     1.163166     1.233252
# min                         0.000000     1.000000     1.000000
# 25%                         0.000000     3.044000     1.000000
# 50%                         0.000000     4.042000     3.000000
# 75%                         2.000000     5.040000     3.000000
# max                        45.000000     6.680000     5.000000
#
#        AGE_AT_DIAGNOSIS    OS_MONTHS   RFS_MONTHS
# count       1985.000000  1981.000000  1985.000000
# mean          61.100544   125.244271   110.117406
# std           12.948374    76.111772    76.297209
# min           21.930000     0.000000     0.000000
# 25%           51.450000    60.866667    41.740000
# 50%           61.840000   116.466667   100.720000
# 75%           70.610000   185.133333   167.760000
# max           96.290000   355.200000   346.380000

# %%
df_patient_MTST.describe()
# Out:
#        LYMPH_NODES_EXAMINED_POSITIVE         NPI      COHORT  \
# count                     334.000000  303.000000  513.000000
# mean                        1.640719    4.130937    4.000000
# std                         3.628750    1.344243    3.370367
# min                         0.000000    1.140000    1.000000
# 25%                         0.000000    3.280000    1.000000
# 50%                         0.000000    4.320000    1.000000
# 75%                         2.000000    5.000000    7.000000
# max                        30.000000    7.200000    9.000000
#
#        AGE_AT_DIAGNOSIS  OS_MONTHS  RFS_MONTHS
# count        513.000000        0.0  403.000000
# mean          57.788168        NaN  102.562804
# std           13.037440        NaN   77.394361
# min           27.000000        NaN    0.030000
# 25%           47.550000        NaN   37.170000
# 50%           58.000000        NaN   86.880000
# 75%           67.000000        NaN  166.890000
# max           89.000000        NaN  384.210000

# %% [markdown]
# nullを含む行の確認

# %%
df_patient_MB[df_patient_MB.isnull().any(axis=1)]
# Out:
#      PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY  \
# 0       MB-0000                           10.0  6.044         NaN
# 2       MB-0005                            1.0  4.030        High
# 3       MB-0006                            3.0  4.050    Moderate
# 6       MB-0014                            1.0  4.020    Moderate
# 7       MB-0020                            NaN  6.130        High
# ...         ...                            ...    ...         ...
# 1979    MB-7294                            1.0  4.030        High
# 1981    MB-7296                            1.0  5.040        High
# 1982    MB-7297                           45.0  6.050        High
# 1983    MB-7298                           12.0  5.050    Moderate
# 1984    MB-7299                            1.0  5.040        High
#
#      CHEMOTHERAPY  COHORT    ER_IHC HER2_SNP6 HORMONE_THERAPY  \
# 0              NO     1.0   Positve   NEUTRAL             YES
# 2             YES     1.0   Positve   NEUTRAL             YES
# 3             YES     1.0   Positve   NEUTRAL             YES
# 6             YES     1.0   Positve      LOSS             YES
# 7             YES     1.0  Negative   NEUTRAL              NO
# ...           ...     ...       ...       ...             ...
# 1979           NO     4.0   Positve      GAIN             YES
# 1981           NO     4.0   Positve      GAIN              NO
# 1982           NO     4.0   Positve   NEUTRAL             YES
# 1983           NO     4.0   Positve   NEUTRAL             YES
# 1984           NO     4.0   Positve   NEUTRAL             YES
#
#      INFERRED_MENOPAUSAL_STATE     SEX INTCLUST  AGE_AT_DIAGNOSIS   OS_MONTHS  \
# 0                         Post  Female     4ER+             75.65  140.500000
# 2                          Pre  Female        3             48.87  163.700000
# 3                          Pre  Female        9             47.68  164.933333
# 6                         Post  Female        3             56.45  164.333333
# 7                         Post  Female     4ER-             70.00   22.400000
# ...                        ...     ...      ...               ...         ...
# 1979                      Post  Female        1             59.20   82.733333
# 1981                       Pre  Female        5             42.88   44.733333
# 1982                      Post  Female        1             62.90  175.966667
# 1983                      Post  Female        1             61.16   86.233333
# 1984                      Post  Female       10             60.02  201.900000
#
#        OS_STATUS CLAUDIN_SUBTYPE              THREEGENE          VITAL_STATUS  \
# 0       0:LIVING     claudin-low              ER-/HER2-                Living
# 2     1:DECEASED            LumB                    NaN       Died of Disease
# 3       0:LIVING            LumB                    NaN                Living
# 6       0:LIVING            LumB                    NaN                Living
# 7     1:DECEASED          Normal              ER-/HER2-       Died of Disease
# ...          ...             ...                    ...                   ...
# 1979  1:DECEASED            LumB  ER+/HER2- High Prolif       Died of Disease
# 1981  1:DECEASED            LumB                    NaN       Died of Disease
# 1982  1:DECEASED            LumB                    NaN       Died of Disease
# 1983  1:DECEASED            LumB  ER+/HER2- High Prolif  Died of Other Causes
# 1984  1:DECEASED            LumB  ER+/HER2- High Prolif  Died of Other Causes
#
#      LATERALITY RADIO_THERAPY HISTOLOGICAL_SUBTYPE     BREAST_SURGERY  \
# 0         Right           YES           Ductal/NST         MASTECTOMY
# 2         Right            NO           Ductal/NST         MASTECTOMY
# 3         Right           YES                Mixed         MASTECTOMY
# 6         Right           YES           Ductal/NST  BREAST CONSERVING
# 7          Left           YES              Lobular         MASTECTOMY
# ...         ...           ...                  ...                ...
# 1979        NaN            NO           Ductal/NST         MASTECTOMY
# 1981        NaN           YES           Ductal/NST         MASTECTOMY
# 1982       Left           YES           Ductal/NST         MASTECTOMY
# 1983        NaN            NO           Ductal/NST         MASTECTOMY
# 1984        NaN           YES           Ductal/NST  BREAST CONSERVING
#
#           RFS_STATUS  RFS_MONTHS
# 0     0:Not Recurred      138.65
# 2         1:Recurred      151.28
# 3     0:Not Recurred      162.76
# 6     0:Not Recurred      162.17
# 7         1:Recurred       11.74
# ...              ...         ...
# 1979      1:Recurred       81.64
# 1981      1:Recurred       16.09
# 1982      1:Recurred      121.18
# 1983  0:Not Recurred       85.10
# 1984  0:Not Recurred      199.24
#
# [466 rows x 24 columns]

# %% [markdown]
# dtypesの修正

# %%
# 死因が乳がん以外（と推定されるもの）と、drop_columnsに含まれる列、nanを含む行の削除
df_patient_MB_filtered=df_patient_MB[df_patient_MB['VITAL_STATUS']!='Died of Other Causes']
df_patient_living=df_patient_MB_filtered[df_patient_MB_filtered['VITAL_STATUS']!='Living'].drop(drop_columns, axis=1).dropna()
df_patient_dead=df_patient_MB_filtered[df_patient_MB_filtered['VITAL_STATUS']!='Diof Disease'].drop(drop_columns, axis=1).dropna()
